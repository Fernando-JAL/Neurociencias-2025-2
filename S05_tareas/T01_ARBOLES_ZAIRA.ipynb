# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL.ImageColor import colormap

# %%
path = r"/Users/ZvalEnes/Desktop/Neurociencias-2025-2/S03_datasets/iris/iris.csv"
df = pd.read_csv(path)

# %%
X, y = df.iloc[:, :-1], df.iloc[:, -1]

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
clf = DecisionTreeClassifier(criterion = "entropy", random_state=99)
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=99)

# %%
plt.figure(figsize=(12, 8))
plot_tree(clf, filled=True, feature_names=df.columns[:-1], class_names=df['Species'].unique())
# Out:
# [Text(0.5, 0.9166666666666666, 'Petal.Length <= 2.45\nentropy = 1.585\nsamples = 150\nvalue = [50, 50, 50]\nclass = setosa'),
#  Text(0.4230769230769231, 0.75, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]\nclass = setosa'),
#  Text(0.46153846153846156, 0.8333333333333333, 'True  '),
#  Text(0.5769230769230769, 0.75, 'Petal.Width <= 1.75\nentropy = 1.0\nsamples = 100\nvalue = [0, 50, 50]\nclass = versicolor'),
#  Text(0.5384615384615384, 0.8333333333333333, '  False'),
#  Text(0.3076923076923077, 0.5833333333333334, 'Petal.Length <= 4.95\nentropy = 0.445\nsamples = 54\nvalue = [0, 49, 5]\nclass = versicolor'),
#  Text(0.15384615384615385, 0.4166666666666667, 'Petal.Width <= 1.65\nentropy = 0.146\nsamples = 48\nvalue = [0, 47, 1]\nclass = versicolor'),
#  Text(0.07692307692307693, 0.25, 'entropy = 0.0\nsamples = 47\nvalue = [0, 47, 0]\nclass = versicolor'),
#  Text(0.23076923076923078, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
# ...

# %%
observado = clf.predict(X)
pd.crosstab(y, observado)
# Out:
# col_0       setosa  versicolor  virginica
# Species
# setosa          50           0          0
# versicolor       0          50          0
# virginica        0           0         50

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import confusion_matrix

# Cargar el conjunto de datos
df = pd.read_csv('/Users/ZvalEnes/Desktop/Neurociencias-2025-2/S03_datasets/iris/iris.csv')

# %%
# Dividir los datos en características y variable objetivo
X, y = df.iloc[:, :-1], df.iloc[:, -1]

# %%
# Entrenar un clasificador de árbol de decisión con una profundidad máxima de 3
clf = DecisionTreeClassifier(criterion="entropy", max_depth=3, random_state=99)
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=99)

# %%
# Visualizar el árbol de decisión con colores personalizados
plt.figure(figsize=(12, 8))
plot_tree(clf, filled=True, feature_names=df.columns[:-1], class_names=df['Species'].unique())
plt.show()

# %%
# Predecir los valores observados
observado = clf.predict(X)

# %%
# Crear una matriz de confusión
conf_matrix = confusion_matrix(y, observado)
conf_matrix_df = pd.DataFrame(conf_matrix, index=df['Species'].unique(), columns=df['Species'].unique())

# %%
# Graficar la matriz de confusión
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='terrain')
plt.ylabel('Actual')
plt.xlabel('Predicho')
plt.title('Matriz de Confusión')
plt.show()
