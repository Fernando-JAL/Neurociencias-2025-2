# %% [markdown]
# # K-means
# Es posible "plantar" las semillas en diferentes puntos (parte de la funcion) y que se muevan con cada iteracion

# %% [markdown]
# #### ITERANDO K-MEANS

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

df = pd.read_csv(r"C:\Users\vladi\OneDrive\Documentos\datas\iris.csv")

seeds = np.array([[], [], []])
df2 = df.iloc[:, [0, 2]]
df2_std = StandardScaler().fit_transform(df2)

no_clusters = 3
kmeans = KMeans(n_clusters=no_clusters)
kmeans.fit(df2_std)
df2_std_df = pd.DataFrame(data=df2,  )
# Out:
# C:\Users\vladi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# <Axes: xlabel='Petal.Length', ylabel='Sepal.Length'>

# %%
seeds = np.array([-1, 1.3],[-0.5, 2],[-1, 2.7])
frames= 5
fig, axes = plt.subplots(1,frames, figsize=(15, 5))
for frame in range(1, frames+1):
    kmeans = KMeans(n_clusters=3, max_iter=3*idx, init=seeds)
    kmeans.fit(df2_std)
    labels = kmeans.labels
    cluster_centers = kmeans.cluster_centers_

    sns.scatterplot(data=df2_std_df, x='Petal.Length', y='Sepal.Length', hue=labels, ax=axes[idx-1]).set_title(f"Frame{idx}")
    sns.scatterplot(x=cluster_centers[:, 0], y= cluster_centers[:,1], marker="x", s= 250, color= "r", ax= axes[idx-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 seeds = np.array([-1, 1.3],[-0.5, 2],[-1, 2.7])
#       2 frames= 5
#       3 fig, axes = plt.subplots(1,frames, figsize=(15, 5))
#
# TypeError: array() takes from 1 to 2 positional arguments but 3 were given
