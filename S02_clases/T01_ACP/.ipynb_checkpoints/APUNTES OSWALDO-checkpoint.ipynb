# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
size = 1000
x = np.random.normal(loc=0, scale=8, size=size)
y = np.random.normal(loc=0, scale=2, size=size)

# %%
plt.scatter(x, y)
plt.axis('equal')
plt.show()

# %%
mean = [0, 0]
cov = [[3, 3], [3, 4]]
size = 500
X = np.random.multivariate_normal(mean=mean, cov=cov, size=size)

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.axis('equal')
plt.show()

# %%
X
# Out:
# array([[ 1.35806809e+00,  8.07900033e-01],
#        [-8.36274186e-01, -1.39369244e+00],
#        [ 4.76461050e-01,  2.58710502e-01],
#        [ 1.45395147e+00,  3.66109472e+00],
#        [ 3.24972630e+00,  2.95738671e+00],
#        [-1.71334004e+00, -1.24988637e+00],
#        [ 3.62408025e-01,  2.24029797e+00],
#        [ 8.72169765e-01,  2.18994469e+00],
#        [-3.35191568e+00, -4.05140234e+00],
#        [ 3.57730206e-01,  2.76462111e-01],
#        [-1.40298173e+00, -4.30971965e-01],
#        [-4.92471381e-01,  2.26806020e+00],
#        [-1.48500405e+00, -2.82772053e+00],
#        [ 1.77952356e+00,  8.85289743e-01],
#        [ 1.01183921e+00,  2.83057911e+00],
#        [-1.65009970e+00, -1.79430496e+00],
#        [-3.69226493e+00, -4.41334141e+00],
#        [-4.24002612e-01, -8.58798041e-01],
#        [ 1.11529659e+00,  1.71907108e+00],
#        [ 1.99585298e+00,  1.30757814e+00],
#        [ 9.66168777e-01,  7.65110085e-01],
#        [-1.58794581e+00, -2.99695242e+00],
#        [-1.98275057e+00, -2.47567296e+00],
#        [-9.68619191e-01, -1.03452774e+00],
#        [ 6.87305249e-02,  6.03940534e-01],
#        [-1.39164479e+00, -1.05246060e+00],
#        [-1.72408844e+00, -1.63590453e+00],
#        [ 4.41988996e-01, -1.57006302e-01],
#        [-2.30969133e-01,  2.27660456e-01],
#        [-1.49196892e+00, -1.33935351e+00],
#        [ 6.07824368e-01,  8.61223889e-02],
#        [-3.54374946e-01, -7.15679311e-01],
#        [-2.30478992e+00, -1.95847903e+00],
#        [ 8.35357643e-01,  1.74489174e+00],
#        [ 5.59235829e-01,  9.13679580e-01],
#        [-1.06825481e+00, -2.36903606e+00],
#        [-6.26681572e-01, -9.84024912e-01],
#        [ 2.16133308e+00,  1.32149911e-01],
#        [ 1.23824458e+00,  1.58790853e+00],
#        [-1.77383194e+00, -6.69161083e-01],
#        [-1.75506520e+00, -3.06575337e+00],
#        [-2.36252219e+00, -1.47967858e+00],
#        [ 1.34636396e+00,  2.34502566e+00],
#        [-1.04899564e+00, -2.99459714e+00],
#        [-1.05821637e+00, -3.30781524e+00],
#        [-1.13225280e-01, -8.07996123e-01],
#        [ 2.47113540e+00,  2.35041184e+00],
#        [-2.14627388e+00, -9.05721124e-02],
#        [-6.52446176e-01,  1.74410248e+00],
#        [-1.30830461e+00, -1.49031110e+00],
#        [-1.47601994e+00, -3.17509050e-03],
#        [-6.36955744e-01, -6.50644225e-01],
#        [ 4.05898487e-01, -9.35076175e-01],
#        [ 1.49105602e+00,  5.25348157e-02],
#        [ 4.37986683e+00,  2.83976703e+00],
#        [-2.43441438e+00, -1.94985890e+00],
#        [ 8.79754974e-01,  1.82688398e+00],
#        [-5.11130821e-01, -1.99584536e+00],
#        [ 9.50566411e-01,  2.27128735e-03],
#        [ 2.48160179e+00,  7.06931682e-01],
#        [ 1.53791563e+00, -5.60369775e-01],
#        [ 6.95885947e-01,  1.86834059e+00],
#        [-1.60653766e+00, -8.97705290e-01],
#        [ 3.80578649e-01,  1.01466426e-01],
#        [-3.51082125e+00, -3.43977589e+00],
#        [ 2.31455222e+00,  2.09243588e+00],
#        [ 4.19969137e-01,  5.27383535e-01],
#        [ 6.61307781e-01,  2.40521912e-02],
#        [-1.51865410e+00, -3.04382321e+00],
#        [-1.86366328e+00, -4.08664922e-01],
#        [-6.92489214e-01, -1.25237939e+00],
#        [ 2.86217009e+00,  3.54340837e+00],
#        [-2.55051409e+00, -2.80758938e+00],
#        [ 2.52117732e+00,  1.99076161e+00],
#        [ 1.72039347e-02, -2.03822554e+00],
#        [-4.97936038e+00, -3.33542584e+00],
#        [ 2.46666506e-01,  1.08181573e+00],
#        [ 1.93553580e+00,  2.68279374e+00],
#        [ 1.74648009e+00,  1.96770582e+00],
#        [-2.63504658e+00, -1.41528826e+00],
#        [-1.64736800e+00, -1.48272668e+00],
#        [ 1.35528419e+00,  7.82095396e-01],
#        [ 1.88341013e+00,  1.18724728e+00],
#        [-1.41637014e+00, -2.99941972e+00],
#        [ 7.30105749e-02,  1.17671654e+00],
#        [-3.14981013e+00, -3.02388078e+00],
#        [-1.03985966e+00, -5.37785832e-02],
#        [-1.17651054e+00,  9.21244089e-01],
#        [-8.10357474e-01, -2.51164131e+00],
#        [-4.36894927e-01,  8.67150782e-01],
#        [ 1.60395229e-01, -1.01429002e-01],
#        [ 1.09182913e+00,  1.81653132e+00],
#        [-1.49046377e+00, -1.18713938e+00],
#        [ 3.37149015e+00,  1.98201798e+00],
#        [ 2.23128169e+00,  2.10075006e+00],
#        [-1.14625401e+00, -7.24456209e-01],
#        [ 2.89628797e+00,  2.77241494e+00],
#        [-1.11740307e+00, -7.66303112e-01],
#        [ 6.91147658e-01, -2.71821789e-01],
#        [-1.75365180e+00, -2.27722580e+00],
#        [ 4.29188425e+00,  4.81598960e+00],
#        [ 6.40132944e-02, -4.11252673e-01],
#        [ 1.10413170e+00, -8.30267343e-01],
#        [-3.35472352e-01, -2.66871793e-01],
#        [ 6.64351681e-01,  9.28244582e-01],
#        [ 1.43052914e+00,  1.14870128e+00],
#        [-2.49256575e+00, -2.48977902e+00],
#        [-9.92411404e-01, -1.56574116e+00],
#        [ 1.80309128e+00,  3.44280620e+00],
#        [ 1.67984034e+00,  9.68753447e-01],
#        [ 1.69841049e-01,  8.13442367e-01],
#        [-2.58579950e+00, -8.46695379e-01],
#        [-2.28360150e+00, -2.47411712e+00],
#        [-2.55392254e+00, -1.50771204e+00],
#        [-3.30635567e+00, -4.41861946e+00],
#        [ 8.19068418e-01,  3.16822382e-01],
#        [ 2.06674018e+00,  9.57898279e-01],
#        [ 1.17936482e+00,  1.38528760e+00],
#        [ 4.59898600e+00,  4.48799369e+00],
#        [-4.43807497e-01,  3.86053918e-01],
#        [ 5.45028753e-01,  1.42108938e+00],
#        [-1.28031367e+00, -1.55259238e+00],
#        [ 1.43142929e+00,  3.64401677e+00],
#        [-2.19319450e+00, -4.11081817e+00],
#        [ 8.58663432e-01,  1.90721570e+00],
#        [ 1.42061155e+00,  4.23004943e-01],
#        [ 1.87578053e+00,  2.13749420e+00],
#        [-2.12146879e+00, -1.19949613e+00],
#        [ 1.63825698e+00,  1.09408591e+00],
#        [-2.98936838e+00, -2.98768956e+00],
#        [-2.04815144e+00, -2.22542372e+00],
#        [-1.01968391e+00, -4.72137443e-01],
#        [ 2.64509453e+00,  4.33607435e+00],
#        [-2.58004656e+00, -2.44989193e+00],
#        [ 3.49161878e-01,  1.91273778e-02],
#        [-8.68489206e-01,  3.18184618e-02],
#        [ 2.63518927e-01, -2.10981000e-02],
#        [-7.28574668e-01, -2.87554587e+00],
#        [-2.65219192e+00, -2.11148896e+00],
#        [ 1.46522297e+00,  2.36823595e-01],
#        [ 2.33953865e+00,  1.53639729e+00],
#        [ 1.26032610e+00,  1.45979416e+00],
#        [ 1.75919860e+00,  2.14427387e+00],
#        [ 8.29032910e-01,  1.24245271e+00],
#        [-1.87909304e-01, -1.18587879e+00],
#        [-7.80936267e-01,  6.47070460e-01],
#        [ 2.65573709e+00,  1.41304370e+00],
#        [-2.01683527e+00, -6.00809152e-01],
#        [ 9.96215576e-01,  8.57334583e-01],
#        [ 2.63219672e+00,  1.18647824e+00],
#        [-1.37798674e+00, -7.71323020e-01],
#        [ 3.05902614e-01, -1.84199839e-01],
#        [-1.47340268e+00, -1.66727529e+00],
#        [ 4.48348567e-01,  1.04303725e+00],
#        [ 8.40911439e-01,  7.01087215e-01],
#        [-1.24636578e+00, -1.01946115e+00],
#        [ 8.37599635e-01,  1.17926247e+00],
#        [-2.14163672e+00, -2.43816370e+00],
#        [ 6.97382242e-01,  6.92081233e-01],
#        [-5.62633019e-02, -9.30874941e-01],
#        [ 2.33317807e+00,  1.82251213e+00],
#        [-2.03018632e+00, -3.54545174e+00],
#        [-2.56207184e+00, -2.41242461e+00],
#        [ 5.48095237e-01, -1.09953154e+00],
#        [ 4.93197324e-01, -1.10847210e+00],
#        [ 1.21821682e+00,  2.56177901e+00],
#        [ 2.33938079e+00,  2.96702174e+00],
#        [ 2.12199950e-01,  1.49253313e-01],
#        [-6.96758434e-01, -1.21071263e+00],
#        [ 4.90425024e-01, -1.72483001e+00],
#        [ 1.91157490e+00,  1.95933334e+00],
#        [ 9.45850682e-01, -5.34409166e-01],
#        [-7.02270193e-01,  5.15898859e-01],
#        [ 1.91723888e+00,  1.68006890e+00],
#        [ 3.37169631e+00,  2.29588080e+00],
#        [ 1.06595937e+00,  5.03081040e-01],
#        [-2.43940683e-01, -7.06537012e-01],
#        [ 7.36538309e-01,  5.33489928e-01],
#        [ 2.25786062e-01, -2.63226746e-01],
#        [ 2.91111266e-01,  1.32037287e+00],
#        [-2.01560996e+00, -7.32633123e-01],
#        [ 1.68581671e+00,  2.58567750e+00],
#        [-3.96143381e-01,  5.88697833e-01],
#        [-1.07188305e+00, -9.06542396e-01],
#        [-3.59539443e+00, -4.92998379e+00],
#        [ 6.35881715e-01,  2.53714815e-01],
#        [ 8.48456082e-01, -3.28105895e-01],
#        [-2.88225224e+00, -2.70291045e+00],
#        [-3.22378737e+00, -3.84792389e+00],
#        [ 5.73193246e-01,  6.11685230e-01],
#        [-3.06609456e+00, -3.34044397e+00],
#        [-2.52379792e-01,  1.56778334e+00],
#        [-1.95526848e+00, -2.46075948e+00],
#        [-5.13243931e-03, -1.56615448e+00],
#        [ 8.26418115e-01,  8.06130423e-01],
#        [-2.51887041e+00, -3.57160532e+00],
#        [ 1.12503896e+00,  1.56551019e+00],
#        [-1.21516487e+00, -1.52379415e+00],
#        [ 2.83060813e+00,  1.74533158e+00],
#        [-1.77044251e+00, -2.54225356e+00],
#        [-1.58028018e+00, -1.27425829e+00],
#        [ 2.94947876e+00,  2.04505939e+00],
#        [-1.55500285e+00, -2.43579063e+00],
#        [-4.18166561e+00, -5.10368395e+00],
#        [ 9.71273076e-01,  1.02350130e+00],
#        [-2.74464598e+00, -2.45794089e+00],
#        [-2.75988966e+00, -4.63253014e+00],
#        [ 8.29252165e-01,  1.42640258e+00],
#        [ 1.14398589e+00, -4.59401036e-01],
#        [ 1.52076536e+00,  1.37252962e+00],
#        [ 8.81597044e-01,  2.53628715e+00],
#        [-2.83647885e+00, -1.82166249e+00],
#        [-1.78609029e+00, -2.11231171e+00],
#        [ 2.26141805e+00,  2.86886957e+00],
#        [ 4.20863760e-01,  2.09345177e-01],
#        [-3.12114823e+00, -2.54314995e+00],
#        [-2.23678309e+00, -3.67661873e+00],
#        [ 1.34130657e+00,  2.00355470e+00],
#        [ 5.67622120e-01,  1.82252396e+00],
#        [-1.34061269e+00, -2.10629172e-01],
#        [ 1.24827502e+00,  2.88698014e+00],
#        [-6.90606882e-01, -1.12268451e+00],
#        [-1.71276942e+00, -1.76872762e+00],
#        [-1.19025710e+00, -1.70062041e+00],
#        [-6.73896963e-01, -1.20235258e+00],
#        [ 1.25132673e+00,  8.67727169e-01],
#        [-1.49302966e+00, -1.31008109e+00],
#        [ 3.48236930e-01,  3.53755397e-01],
#        [-1.71808124e+00, -2.23381095e+00],
#        [ 8.33687316e-02,  8.14131108e-03],
#        [ 7.68182381e-01,  1.51745018e+00],
#        [ 1.76156603e+00,  3.15165143e+00],
#        [ 2.96898683e+00,  2.84445777e+00],
#        [-2.91559817e+00, -3.33003629e+00],
#        [-5.97986572e-01, -1.22689249e+00],
#        [ 7.76593468e-01,  6.58138588e-01],
#        [ 1.23293741e+00,  2.04870981e+00],
#        [-3.31634948e-01, -1.14424838e-01],
#        [ 2.10556949e+00,  3.77983867e+00],
#        [-1.21209022e+00, -2.92189569e-01],
#        [-1.53799526e+00, -1.19964304e+00],
#        [-3.98825277e-01, -4.39401190e-01],
#        [-4.45713821e-01, -3.86293289e-01],
#        [-7.06491735e-01, -3.20953952e-01],
#        [-8.10623211e-01,  1.18810211e-01],
#        [ 2.70253815e+00,  3.35743518e+00],
#        [-2.60163445e+00, -1.56924697e+00],
#        [ 1.07496088e+00, -3.85156664e-01],
#        [ 6.83069084e-01,  1.76691780e+00],
#        [-2.10483757e+00, -2.33587876e+00],
#        [ 2.04552096e+00,  9.81680863e-01],
#        [-5.94676272e-02, -3.91376378e-01],
#        [ 2.22314714e-01,  2.16425897e+00],
#        [ 3.21429312e+00,  8.46106538e-01],
#        [ 1.08944503e+00,  9.59243000e-01],
#        [-1.03932001e+00,  6.00227199e-01],
#        [ 3.14983256e+00,  4.33119417e+00],
#        [-1.18439723e+00, -1.88710311e-01],
#        [-1.20623837e+00, -8.75219672e-01],
#        [ 1.35907187e+00,  3.58318640e+00],
#        [-2.43009314e+00, -3.23016324e+00],
#        [ 2.56473766e+00,  1.49911898e+00],
#        [ 1.78329422e+00,  2.93689336e+00],
#        [ 1.73308788e+00,  5.16051668e-01],
#        [ 9.43119615e-01,  7.82421502e-01],
#        [-1.00074544e+00, -1.52234395e+00],
#        [-5.00592566e-01, -7.81113348e-01],
#        [ 2.84573447e+00,  2.43737414e+00],
#        [-8.52605211e-01, -4.07929077e-01],
#        [-3.05556206e+00, -1.86720140e+00],
#        [-1.74582509e+00, -2.66646180e+00],
#        [-3.14034237e-01, -5.59321302e-02],
#        [ 2.37504309e+00,  3.33387763e+00],
#        [ 1.14538488e+00, -5.62607206e-01],
#        [-5.93670100e-01, -4.65529380e-01],
#        [ 2.72941538e+00,  3.58437952e+00],
#        [-5.02893903e+00, -4.88770902e+00],
#        [-4.72783505e-01,  1.03973809e+00],
#        [-1.47648794e+00, -3.45003549e-01],
#        [ 1.11489117e+00,  2.64274435e+00],
#        [-2.39025196e+00, -1.88828815e+00],
#        [-9.38134162e-01, -2.63911488e-01],
#        [ 1.10015893e-01, -2.08451451e-01],
#        [-1.38989512e+00, -1.62186054e+00],
#        [ 1.50495070e+00, -3.19796566e-01],
#        [ 5.94907340e-01,  1.44758822e+00],
#        [-1.82272893e+00, -2.11450942e+00],
#        [-1.71377525e-01,  6.22307782e-01],
#        [ 1.65378114e+00,  2.33669212e+00],
#        [-1.27261496e-01,  2.47706993e-01],
#        [-5.29544997e-01, -1.36209097e+00],
#        [-7.49785591e-01, -1.85765476e+00],
#        [-1.50551053e+00,  2.15082034e-01],
#        [-1.89134916e+00, -1.84927056e+00],
#        [-1.25203587e-01,  1.40435546e-01],
#        [ 1.95514059e+00,  2.59567082e+00],
#        [ 1.35334608e+00,  4.63965738e-01],
#        [ 1.44013124e+00,  3.35827713e+00],
#        [ 3.10874261e-01, -2.75079631e-01],
#        [ 1.96260747e+00,  2.99105194e+00],
#        [-1.54228976e+00, -1.34202663e+00],
#        [ 7.86694078e-01, -6.10436916e-01],
#        [ 1.17128081e-02,  5.82755886e-01],
#        [ 6.46118128e-01,  1.11893181e-01],
#        [-3.69624662e+00, -3.22509569e+00],
#        [ 2.15024249e-01,  4.75527589e-01],
#        [ 9.92435837e-01,  1.51961613e+00],
#        [-9.00451046e-01, -3.49037836e-01],
#        [-2.23212522e+00, -2.70244936e+00],
#        [ 3.36216666e-01,  1.03095031e+00],
#        [ 1.75134015e+00,  1.92327872e+00],
#        [ 2.09288783e-01,  1.39009953e+00],
#        [-1.09986579e+00, -2.72906235e+00],
#        [ 3.15640545e+00,  2.73892425e+00],
#        [-1.58962268e-01, -1.94619345e+00],
#        [-4.55183030e-01, -8.89686772e-01],
#        [ 1.14898087e+00,  1.69777080e+00],
#        [ 3.07312322e+00,  2.80792663e+00],
#        [ 1.20159146e+00,  1.31887534e+00],
#        [-3.47135081e+00, -4.79504801e+00],
#        [-2.61205061e-01, -1.47586308e+00],
#        [-1.40161830e+00, -2.50235067e+00],
#        [ 6.33406525e-01,  1.70592249e+00],
#        [-4.14450258e+00, -3.91967447e+00],
#        [ 3.97014853e-01,  1.32941838e+00],
#        [ 1.28995510e+00,  2.06690421e+00],
#        [ 8.02615345e-01,  8.81048614e-01],
#        [-9.72213616e-01, -4.38639433e-01],
#        [ 1.78146769e-01,  2.61276674e+00],
#        [ 8.37254239e-01,  2.27521683e-01],
#        [-4.66878169e-02,  8.20853315e-02],
#        [-3.34565275e+00, -4.01587649e+00],
#        [ 8.06761886e-01,  5.47006945e-01],
#        [-3.94663853e+00, -4.08094173e+00],
#        [-1.19825696e+00, -2.65206249e+00],
#        [-6.74214133e-02, -4.19359868e-01],
#        [ 2.06992325e+00,  1.48862161e+00],
#        [-1.67731562e+00, -3.26507000e+00],
#        [-1.05796122e+00, -1.03464831e+00],
#        [-1.36536710e+00, -1.35615493e+00],
#        [ 1.74936366e+00,  2.46883317e-01],
#        [-1.34665918e+00, -2.45933357e+00],
#        [-1.23031360e+00, -2.00636005e+00],
#        [-2.10220034e+00, -1.30076064e+00],
#        [-1.11667726e+00, -7.08540179e-01],
#        [ 4.02485139e-01,  1.22049916e+00],
#        [ 6.38775822e-03, -1.21359607e-01],
#        [-1.29735699e+00, -1.65279968e+00],
#        [ 1.21202423e+00,  1.14096114e+00],
#        [-2.28061034e+00, -1.83879572e+00],
#        [-8.17962088e-01, -1.82176725e+00],
#        [ 2.45237521e+00,  3.02808195e+00],
#        [-6.87241023e-01, -4.45292813e-02],
#        [ 2.78359335e-01,  1.06362825e+00],
#        [ 7.02494320e-01, -3.86503432e-02],
#        [ 2.95655105e-01, -2.86953903e-01],
#        [-1.22717723e+00, -5.59167644e-02],
#        [-2.74557766e+00, -3.82375532e+00],
#        [ 2.48553047e-01,  2.88943666e+00],
#        [-2.66768598e+00, -3.54883439e+00],
#        [ 1.34203209e+00,  1.32321455e+00],
#        [-3.10584672e+00, -3.22437427e+00],
#        [-1.46807725e+00, -1.91029750e+00],
#        [ 1.49514574e+00,  2.09177445e+00],
#        [-2.32536690e+00, -3.34063217e+00],
#        [ 1.16621650e-01, -1.23246053e+00],
#        [-1.78483861e+00, -6.65445535e-01],
#        [ 1.32413751e+00,  3.40775347e-01],
#        [ 9.06888210e-01,  1.63011999e-01],
#        [-3.16444264e-01, -2.73670689e-01],
#        [ 9.69835209e-01,  1.53776253e+00],
#        [-9.35185996e-01, -6.79466100e-01],
#        [ 1.90154734e+00,  2.15991468e+00],
#        [-2.99286432e+00, -3.47823848e+00],
#        [-6.29492202e-01, -1.66501128e-01],
#        [ 3.14145072e-01, -1.01110095e+00],
#        [ 3.62447698e-01, -5.52210744e-01],
#        [ 3.30456181e+00,  3.36747324e+00],
#        [-2.25167191e+00, -5.84365787e-01],
#        [ 3.95217846e+00,  2.50839649e+00],
#        [-8.38073733e-01, -1.88208334e+00],
#        [ 1.40624499e+00,  2.36904849e+00],
#        [-8.57119205e-01, -6.25070342e-01],
#        [ 3.69801735e+00,  2.38805473e+00],
#        [ 3.82875719e+00,  5.22868025e+00],
#        [ 1.70507031e+00,  2.88559401e+00],
#        [ 4.48460677e-01, -2.17416553e-01],
#        [ 1.47673134e+00,  1.04177736e+00],
#        [-1.68373580e+00,  1.47729524e-01],
#        [-1.06447404e+00, -7.81650654e-01],
#        [-4.45592869e-01, -9.37136805e-01],
#        [ 1.66809490e+00,  2.34636877e+00],
#        [ 5.55783386e+00,  4.67700203e+00],
#        [ 1.23336251e+00, -2.34198685e+00],
#        [-3.97036626e-01, -1.25520600e+00],
#        [-5.92906882e-02,  1.07912171e-01],
#        [ 1.06612253e+00,  1.46569235e+00],
#        [ 1.71527066e+00,  1.80279613e+00],
#        [ 5.50769696e-01,  1.98673845e-01],
#        [ 9.36013592e-01,  2.58242712e+00],
#        [ 1.93388126e+00,  2.97625821e+00],
#        [ 3.04308963e+00,  1.59066259e+00],
#        [-1.77934719e+00, -1.78200244e+00],
#        [-1.19832975e-01, -4.64347581e-02],
#        [-2.29759543e+00, -8.75425380e-01],
#        [-3.55932151e+00, -3.43383407e+00],
#        [ 1.63346866e+00,  2.13663781e+00],
#        [-1.12666992e+00,  2.36609667e-01],
#        [-6.55603910e-01, -2.22650582e+00],
#        [ 9.81753307e-01,  1.26693274e+00],
#        [-1.80713227e+00, -1.31917441e+00],
#        [ 3.03759913e-01, -1.87544325e-02],
#        [ 1.27869333e+00,  1.15408376e+00],
#        [ 2.74954335e+00,  2.86481102e+00],
#        [ 3.87326473e+00,  3.42924109e+00],
#        [-1.22951448e+00, -1.53898375e+00],
#        [ 3.68642638e-01,  1.03452919e+00],
#        [ 5.81805244e-02,  3.48872872e-02],
#        [-6.45740269e-01, -4.78070408e-01],
#        [ 1.12811401e+00,  9.13024323e-01],
#        [ 1.66984855e+00,  1.81924521e+00],
#        [ 1.38749618e-01, -7.20697900e-01],
#        [-2.36341288e+00,  7.68955762e-02],
#        [-9.58245929e-01, -2.04321883e+00],
#        [ 1.58238019e+00,  2.63171687e+00],
#        [-8.02017820e-01, -1.46888588e+00],
#        [-1.68715652e+00, -2.28777196e+00],
#        [-3.73544559e+00, -2.62419396e+00],
#        [ 1.81276905e+00,  2.18508481e+00],
#        [-2.49276914e+00, -2.15548692e+00],
#        [ 4.24944785e-01,  8.46107873e-01],
#        [ 1.74599396e+00,  2.55560595e+00],
#        [ 4.38499101e-01, -3.70223536e-01],
#        [-1.47729476e+00, -4.06718310e-01],
#        [ 2.35173960e+00,  8.17462223e-01],
#        [-2.52090601e-01, -1.21615148e-01],
#        [ 1.59361606e+00,  1.98766112e+00],
#        [-2.70413255e+00, -2.58292113e+00],
#        [-1.17200299e+00, -3.93731312e+00],
#        [ 1.61933232e+00,  1.95938115e+00],
#        [ 3.25849495e-01, -3.07165821e-01],
#        [-3.84485071e+00, -2.93452928e+00],
#        [ 6.92666700e-01,  1.44123089e+00],
#        [-2.62725909e+00, -1.97831891e+00],
#        [-2.15994254e+00, -2.62679947e+00],
#        [ 1.64940082e-01,  1.37525735e+00],
#        [-6.62431094e-01, -2.02921954e+00],
#        [ 2.72214648e-01, -1.43807234e+00],
#        [ 1.65564686e+00,  1.89769814e+00],
#        [-2.51497829e-01, -2.83906379e-01],
#        [-6.63789212e-01,  8.18422327e-02],
#        [-2.56040436e+00, -3.60026781e+00],
#        [ 4.88918304e-01,  1.46238170e-01],
#        [-4.50261446e-01, -9.29964105e-01],
#        [ 1.74331853e+00,  2.28827022e+00],
#        [ 4.06005010e-01, -2.98738045e-01],
#        [ 5.90109474e-01,  3.32567473e-01],
#        [ 5.87142549e-01, -1.25513306e+00],
#        [ 8.92191753e-01,  9.92781881e-01],
#        [ 1.04937445e+00,  1.91560891e+00],
#        [-4.19435928e-01,  3.54289774e-01],
#        [-2.13783117e+00, -7.67974633e-01],
#        [-3.22029152e+00, -6.48508391e+00],
#        [ 1.25447991e+00,  1.35846535e+00],
#        [ 8.05535990e-01, -1.07167688e+00],
#        [ 2.16077390e+00,  1.27253075e+00],
#        [ 1.34245328e+00,  1.73512657e+00],
#        [ 9.93245055e-01,  9.08040092e-01],
#        [ 1.18609379e+00, -5.43343559e-01],
#        [-1.35646139e+00, -7.08285785e-01],
#        [-1.36258500e+00, -5.20990747e-01],
#        [ 9.34047218e-01, -2.39663482e-02],
#        [-1.40434243e-01, -2.32671166e-01],
#        [-1.41221482e+00, -3.97066528e+00],
#        [ 1.36712151e+00,  4.37941249e+00],
#        [ 2.96310125e+00,  2.47154954e+00],
#        [ 2.50239666e+00,  4.11571784e+00],
#        [ 1.56386087e+00,  2.42728761e+00],
#        [-3.27257528e+00, -2.17046814e+00],
#        [-1.05734510e+00, -2.69295376e+00],
#        [-1.97580792e-01,  3.30722377e-01],
#        [ 1.53062083e+00,  7.58378534e-01],
#        [-1.47834846e+00, -3.69811445e+00],
#        [ 5.96749724e-01,  1.58576421e+00],
#        [-7.93198628e-01, -5.36830297e-01],
#        [-3.63329106e+00, -3.63632092e+00],
#        [ 1.81266446e+00, -4.93961683e-01],
#        [-5.87308163e-01, -1.03008419e+00],
#        [ 1.87935580e+00,  1.39642194e+00],
#        [-1.28787517e+00, -1.95140465e+00],
#        [-3.05951743e+00, -2.62189619e+00],
#        [ 6.79317716e-01,  3.13476803e-01],
#        [ 8.68959148e-01,  1.97905311e-02],
#        [ 3.26461502e+00,  2.26200012e+00],
#        [-3.74684686e+00, -3.31418749e+00],
#        [ 2.91896411e+00,  3.22683922e+00],
#        [-1.94235620e+00, -1.62097272e+00],
#        [ 5.52044105e-01, -8.10879039e-01],
#        [ 1.28017652e+00, -5.80351142e-01],
#        [ 7.32584915e-01,  2.04227793e-01]])

# %% [markdown]
# ## normalización de los datos

# %%
np.mean(X, axis=0), np.std(X, axis=0)
# Out:
# (array([-0.05659078, -0.09639093]), array([1.77459649, 1.99514649]))

# %%
X_std = (X - np.mean(X, axis=0))/np.std(X, axis=0)

# %%
plt.scatter(X_std[:, 0], X_std[:, 1])

# %% [markdown]
# # Calculo de la covarianza

# %%
X_mean = np.mean(X_std, axis=0)
X_mean
# Out:
# array([-8.43769499e-18,  4.94604357e-17])

# %%
cov_matrix = (X_std - X_mean).T.dot((X_std - X_mean))/(X_std.shape[0]-1)
cov_matrix
# Out:
# array([[1.00200401, 0.86363097],
#        [0.86363097, 1.00200401]])

# %%
np.cov(X_std.T)
# Out:
# array([[1.00200401, 0.86363097],
#        [0.86363097, 1.00200401]])

# %%
eig_vals, eig_vecs = np.linalg.eig(cov_matrix)
eig_vals, eig_vecs
# Out:
# (array([0.13837304, 1.86563498]),
#  array([[-0.70710678, -0.70710678],
#         [ 0.70710678, -0.70710678]]))

# %% [markdown]
# # Calculo de valores y vectores propios con la matriz de correlación

# %%
corr_matrix = np.corrcoef(X_std.T)
corr_matrix
# Out:
# array([[1.        , 0.86190371],
#        [0.86190371, 1.        ]])

# %%
eig_vals_corr, eig_vecs_corr = np.linalg.eig(corr_matrix)
eig_vals_corr, eig_vecs_corr
# Out:
# (array([0.13809629, 1.86190371]),
#  array([[-0.70710678, -0.70710678],
#         [ 0.70710678, -0.70710678]]))

# %% [markdown]
# # Singular Value Decomposition

# %%
u, s, v = np.linalg.svd(X_std.T)
u
# Out:
# array([[-0.70710678, -0.70710678],
#        [-0.70710678,  0.70710678]])

# %%
#La longitud de mi vectr es su norma, la norma se calcula así, los cvectores propios siempre deben estar normalizados. 
#Lamda dice qué tan largo es el vector 
# ya que el solo vale 1, el vector unitario nos da las coordenadas del vector.
#El que sean vectores unitarios hace que el peso de la información recaiga en lamda
np.linalg.norm(eig_vecs[0]), np.linalg.norm(eig_vecs[0])
# Out:
# (1.0, 1.0)

# %%
np.sum(eig_vals)
# Out:
# 2.0040080160320652

# %%
eig_vals
# Out:
# array([0.13837304, 1.86563498])

# %%
#Sacar el porcentaje de cada uno de los vectores 
total_sum = np.sum(eig_vals)

val_porc_eig_val_1 = eig_vals[0]/total_sum * 100
val_porc_eig_val_2 = eig_vals[1]/total_sum * 100
val_porc_eig_val_1, val_porc_eig_val_2
# Out:
# (6.904814716502014, 93.095185283498)

# %%
#Para ordenar los valores propios de mayor a menor hcaemos
eig_pairs = [(eig_vals[i], eig_vecs[i]) for i in range(len(eig_vals))]
eig_pairs
# Out:
# [(0.13837304041086207, array([-0.70710678, -0.70710678])),
#  (1.8656349756212034, array([ 0.70710678, -0.70710678]))]

# %%
eig_pairs.sort(reverse=True)
eig_pairs
# Out:
# [(1.8656349756212034, array([ 0.70710678, -0.70710678])),
#  (0.13837304041086207, array([-0.70710678, -0.70710678]))]

# %%
Total_sum = np.sum(eig_vals)

porc_eig = [eig_val/total_sum * 100 for eig_val, _ in eig_pairs]
cum_porc_eig = np.cumsum(porc_eig)
porc_eig, cum_porc_eig
# Out:
# ([93.095185283498, 6.904814716502014], array([ 93.09518528, 100.        ]))

# %%
#PLOTS
x =['Val prop 1', 'Val prop 2']
plt.bar(x, porc_eig)
plt.plot(x, cum_porc_eig, '.-', c='green', linewidth=5, markersize=20) 
#Estamos viendo graficamente la longitud porcentual de cada lamda
#La recta de arriba indica hasta donde me permito perder de información.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2).fit(X_std)
#PCA es nuestra función
#n_components=2 es la reducción de dimensión
#X_std son los datos

# %%
pca.components_, pca.explained_variance_ #metodo o función para hacer la reducción de dimensiones.
#Los vectores propios son los componentes principales.
# Out:
# (array([[ 0.70710678,  0.70710678],
#         [ 0.70710678, -0.70710678]]),
#  array([1.86563498, 0.13837304]))

# %% [markdown]
# CLASE 24/02/2025

# %%
plt.scatter(X_std[:, 0], X_std[:, 1])
for idx, (eig_vec, eig_val) in enumerate(zip(pca.components_,pca.explained_variance_)):
    plt.plot([0, eig_val*eig_vec[0]], [0, eig_val*eig_vec[1]], color = f"C{idx+2}", linewidth=10)
#son los dos vectores propios multiplicados por los valores propios, el verde es el valor propio 1 por el vec 1, el rojo es el CP 2.
