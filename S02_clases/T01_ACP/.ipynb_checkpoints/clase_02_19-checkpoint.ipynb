# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
size = 1000
x = np.random.normal(loc=0, scale=8, size=size)
y = np.random.normal(loc=0, scale=2, size=size)

# %%
plt.scatter(x, y)
plt.axis('equal')
plt.show()

# %%
mean = [0, 0]
cov = [[3, 3], [3, 4]]
size = 500
X = np.random.multivariate_normal(mean=mean, cov=cov, size=size)

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.axis('equal')
plt.show()

# %%
X
# Out:
# array([[ 1.50252982e+00,  2.27184785e+00],
#        [-1.46883177e+00, -1.08212281e+00],
#        [ 2.49110976e-01, -1.96763159e+00],
#        [-2.14544316e-01,  6.73072410e-01],
#        [-2.33372279e+00,  2.22466623e-01],
#        [-1.50382575e+00, -2.47365048e+00],
#        [ 2.44409609e+00,  2.04994747e+00],
#        [ 1.93053041e+00,  3.16119781e+00],
#        [-4.45091654e-02, -6.99164121e-01],
#        [ 3.26795215e-02, -1.06665291e-01],
#        [-1.02834441e+00, -9.53521985e-01],
#        [ 6.96871013e-01,  1.18023985e+00],
#        [ 2.14789704e+00,  1.90142905e+00],
#        [ 2.35956348e-01, -1.33757390e-01],
#        [ 3.37752545e-01, -2.99600964e-01],
#        [-3.98553806e+00, -3.55781233e+00],
#        [ 6.79251841e-03, -3.65276384e-01],
#        [-7.52655037e-01,  2.47982229e-01],
#        [ 1.05001956e+00,  1.81929100e+00],
#        [-1.75028751e+00, -2.69559051e+00],
#        [ 3.18989434e+00,  3.95892599e+00],
#        [-4.36730130e-01,  1.83774274e-01],
#        [ 2.17686952e+00,  7.45940103e-01],
#        [-1.43516867e+00, -2.15801620e+00],
#        [ 1.82588614e-01, -1.24578941e+00],
#        [ 4.76716215e-01,  3.59647139e-02],
#        [ 9.42946437e-01,  2.53562258e-01],
#        [ 1.96117885e+00,  1.11886823e+00],
#        [ 2.32839843e+00,  9.19270943e-01],
#        [-1.40040382e+00, -3.85418465e-01],
#        [ 1.42567155e+00,  4.52307840e-01],
#        [-8.14903315e-01, -1.42316163e+00],
#        [ 1.31418718e+00,  6.94152225e-01],
#        [-1.68659321e-01, -5.92603143e-01],
#        [-2.90665721e+00, -2.90915864e+00],
#        [ 1.77148866e+00,  2.80422553e+00],
#        [-1.77259100e-01, -7.74347071e-01],
#        [-1.87274041e+00, -1.77313072e+00],
#        [-2.95073518e+00, -3.45186069e+00],
#        [-5.47490165e-01, -1.11021003e+00],
#        [-1.19351980e-01, -6.09257836e-01],
#        [ 7.89423334e-01,  8.50747873e-01],
#        [-4.51725444e-01,  7.73146818e-01],
#        [-2.03015637e-01, -1.06949485e+00],
#        [-2.10584943e+00, -1.89924694e+00],
#        [ 2.12168403e+00,  4.93249606e+00],
#        [ 1.84591420e+00,  8.89841367e-01],
#        [ 4.82467763e-01,  2.13054315e-01],
#        [-2.24430173e+00, -1.73305407e+00],
#        [ 1.96389188e+00,  2.11765182e+00],
#        [-8.56272436e-01, -7.37241804e-01],
#        [-1.01153431e+00, -7.05186951e-01],
#        [-2.57715183e+00, -3.61881293e+00],
#        [-2.29472473e+00, -1.91771140e+00],
#        [ 2.51936956e+00,  3.27324341e+00],
#        [-1.12075006e+00, -2.08177424e+00],
#        [-1.83293276e-01, -7.34487083e-01],
#        [ 2.81367426e+00,  2.93380960e+00],
#        [ 1.33140349e+00,  1.27608491e+00],
#        [ 1.99770167e+00,  1.88837053e+00],
#        [-4.97490673e-01, -3.97466572e-01],
#        [ 5.95656994e-01,  1.61346822e+00],
#        [ 1.44101364e+00,  1.95145661e+00],
#        [-2.87990851e+00, -3.00765072e+00],
#        [-1.27382307e+00, -5.50659031e-01],
#        [-1.90721229e+00, -2.60749995e+00],
#        [-1.21775686e+00, -1.99803100e+00],
#        [ 1.19086761e+00,  1.94077532e+00],
#        [-2.24772777e+00, -1.23947307e+00],
#        [ 2.87333374e+00,  4.55978991e+00],
#        [ 2.96423263e-01, -1.08600509e-01],
#        [ 2.83529926e+00,  1.87480074e+00],
#        [-1.28488793e+00, -4.46130358e-01],
#        [-4.25120354e-01, -1.51667348e+00],
#        [-1.97051582e+00, -1.42375715e+00],
#        [-2.19084644e+00, -3.87679720e+00],
#        [ 5.32586914e-01,  1.09472878e+00],
#        [-3.62192515e+00, -4.64589143e+00],
#        [ 9.07484916e-01, -6.66592063e-01],
#        [-4.49661838e+00, -5.37916300e+00],
#        [-1.67728669e+00, -2.04217960e+00],
#        [-1.88587161e+00, -3.50934563e+00],
#        [-1.04678122e+00, -1.24649526e+00],
#        [-1.62297773e+00, -1.58311981e+00],
#        [-6.22153436e-01,  1.36535458e+00],
#        [ 2.42498332e+00,  5.06634278e+00],
#        [ 2.25127582e+00,  8.56989391e-01],
#        [-1.18858985e-01,  5.92514242e-01],
#        [ 5.46142307e-01,  3.10768307e-01],
#        [-5.23211988e-01,  7.41226969e-02],
#        [-9.20808137e-01, -6.35208962e-01],
#        [-1.62144384e+00, -2.24196525e+00],
#        [ 4.14031020e+00,  2.79758745e+00],
#        [-2.21845196e+00, -3.48400528e+00],
#        [ 3.53947146e+00,  3.25126118e+00],
#        [-1.61210634e+00, -3.03627804e+00],
#        [ 1.65961812e-01, -5.44986204e-01],
#        [-4.83707607e-01,  1.37635951e-01],
#        [ 2.49303357e+00,  1.23293270e+00],
#        [-1.33700238e+00, -4.37729688e-01],
#        [ 3.24539637e+00,  3.32100248e+00],
#        [ 1.65364304e-05,  1.23793426e+00],
#        [-4.49488463e-01,  4.31887024e-01],
#        [ 9.91033075e-01, -6.08756442e-01],
#        [-4.56299535e-01,  5.01133275e-02],
#        [-2.36235124e+00, -1.72295395e+00],
#        [ 3.26829812e+00,  2.69068525e+00],
#        [ 1.72160745e+00,  2.06688812e+00],
#        [-3.07447225e+00, -3.52944093e+00]])

# %% [markdown]
# ## normalización de los datos

# %%
np.mean(X, axis=0), np.std(X, axis=0)
# Out:
# (array([-0.05631999, -0.08970591]), array([1.82376209, 2.10986341]))

# %%
X_std = (X - np.mean(X, axis=0))/np.std(X, axis=0)

# %%
plt.scatter(X_std[:, 0], X_std[:, 1])

# %% [markdown]
# # Calculo de la covarianza

# %%
X_mean = np.mean(X_std, axis=0)
X_mean
# Out:
# array([ 3.95239397e-17, -2.66453526e-17])

# %%
cov_matrix = (X_std - X_mean).T.dot((X_std - X_mean))/(X_std.shape[0]-1)
cov_matrix
# Out:
# array([[1.00200401, 0.88260148],
#        [0.88260148, 1.00200401]])

# %%
np.cov(X_std.T)
# Out:
# array([[1.00200401, 0.88260148],
#        [0.88260148, 1.00200401]])

# %%
eig_vals, eig_vecs = np.linalg.eig(cov_matrix)
eig_vals, eig_vecs
# Out:
# (array([0.11940253, 1.88460549]),
#  array([[-0.70710678, -0.70710678],
#         [ 0.70710678, -0.70710678]]))

# %% [markdown]
# # Calculo de valores y vectores propios con la matriz de correlación

# %%
corr_matrix = np.corrcoef(X_std.T)
corr_matrix
# Out:
# array([[1.        , 0.88083628],
#        [0.88083628, 1.        ]])

# %%
eig_vals_corr, eig_vecs_corr = np.linalg.eig(corr_matrix)
eig_vals_corr, eig_vecs_corr
# Out:
# (array([0.11916372, 1.88083628]),
#  array([[-0.70710678, -0.70710678],
#         [ 0.70710678, -0.70710678]]))

# %% [markdown]
# # Singular Value Decomposition

# %%
u, s, v = np.linalg.svd(X_std.T)
u
# Out:
# array([[-0.70710678, -0.70710678],
#        [-0.70710678,  0.70710678]])

# %%
#La longitud de mi vectr es su norma, la norma se calcula así, los cvectores propios siempre deben estar normalizados. 
#Lamda dice quét tan largo es el vector 
# ya que el solo vale 1, el vector unitario nos da las coordenadas del vector.
#El que sean vectores unitarios hace que el peso de la información recaiga en lamda
np.linalg.norm(eig_vecs[0]), np.linalg.norm(eig_vecs[0])
# Out:
# (1.0, 1.0)

# %%
np.sum(eig_vals)
# Out:
# 2.0040080160320644

# %%
eig_vals
# Out:
# array([0.11940253, 1.88460549])

# %%
#Sacar el porcentaje de cada uno de los vectores 
total_sum = np.sum(eig_vals)

val_porc_eig_val_1 = eig_vals[0]/total_sum * 100
val_porc_eig_val_2 = eig_vals[1]/total_sum * 100
val_porc_eig_val_1, val_porc_eig_val_2
# Out:
# (5.958186248085587, 94.0418137519144)

# %%
#Para ordenar los valores propios de mayor a menor hcaemos
eig_pairs = [(eig_vals[i], eig_vecs[i]) for i in range(len(eig_vals))]
eig_pairs
# Out:
# [(0.11940253002175527, array([-0.70710678, -0.70710678])),
#  (1.884605486010309, array([ 0.70710678, -0.70710678]))]

# %%
eig_pairs.sort(reverse=True)
eig_pairs
# Out:
# [(1.884605486010309, array([ 0.70710678, -0.70710678])),
#  (0.11940253002175527, array([-0.70710678, -0.70710678]))]

# %%
Total_sum = np.sum(eig_vals)

porc_eig = [eig_val/total_sum * 100 for eig_val, _ in eig_pairs]
cum_porc_eig = np.cumsum(porc_eig)
porc_eig, cum_porc_eig
# Out:
# ([94.0418137519144, 5.958186248085587], array([ 94.04181375, 100.        ]))

# %%
#PLOTS
x =['Val prop 1', 'Val prop 2']
plt.bar(x, porc_eig)
plt.plot(x, cum_porc_eig, '.-', c='green', linewidth=5, markersize=20) 
#Estamos viendo graficamente la longitud porcentual de cada lamda
#La recta de arriba indica hasta donde me permito perder de información.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2).fit(X_std)
#PCA es nuestra función
#n_components=2 es la reducción de dimensión
#X_std son los datos

# %%
pca.components_, pca.explained_variance_ #metodo o función para hacer la reducción de dimensiones.
#Los vectores propios son los componentes principales.
# Out:
# (array([[-0.70710678, -0.70710678],
#         [-0.70710678,  0.70710678]]),
#  array([1.88460549, 0.11940253]))
