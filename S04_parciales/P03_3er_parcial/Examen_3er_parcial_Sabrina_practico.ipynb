# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout

from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import shutil
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Primero clasificar las imágenes

# %%
# aqui estan las imgs 
image_dir = "/Users/sabrina/Documents/UNI/A-NEUROCIENCIAS/SEXTO/MODELOS2/Neurociencias-2025-2/S03_datasets/Brain_tumor/Brain Tumor/Brain Tumor"

# aqui se van a guardar 
output_base = "/Users/sabrina/Documents/UNI/A-NEUROCIENCIAS/SEXTO/MODELOS2/Neurociencias-2025-2/S03_datasets/Brain_tumor/Brain Tumor/data"
categories = {1: "tumor", 0: "no_tumor"}

# crear las carpetas 
for subset in ['train', 'test']:
    for label in categories.values():
        os.makedirs(os.path.join(output_base, subset, label), exist_ok=True)

# leer el csv que clasifica las imagenes en 1 tumor y 0 no tumor
df = pd.read_csv("/Users/sabrina/Documents/UNI/A-NEUROCIENCIAS/SEXTO/MODELOS2/Neurociencias-2025-2/S03_datasets/Brain_tumor/Brain Tumor/Brain Tumor/Brain Tumor.csv")

# añadir extensión si falta
df['Image'] = df['Image'].apply(lambda x: f"{x}.jpg" if not x.lower().endswith('.jpg') else x)

# dividir en train y test
train_df, test_df = train_test_split(df, test_size=0.2, stratify=df['Class'], random_state=42)

# para que se muevan las imagenes 
def copiar_imagenes(dataframe, subset):
    for _, row in dataframe.iterrows():
        clase = categories[row['Class']] # 0 o 1
        img_name = row['Image'] # lee la imagen
        origen = os.path.join(image_dir, img_name) # carpeta original
        destino = os.path.join(output_base, subset, clase, img_name) # carpeta a donde va 
        if os.path.exists(origen):
            shutil.copyfile(origen, destino)
        else:
            print(f"Imagen no encontrada: {origen}")

# Copiar archivos
copiar_imagenes(train_df, 'train')
copiar_imagenes(test_df, 'test')

# %% [markdown]
# ### Ahora si la CNN

# %% [markdown]
# - Intenté con 4 capas y salió bastante bien
# - 30% de las neuronas apagadas para que no realice overfitting
# - Usé las mismas funciones que en clase que son bastante eficientes y rápidas

# %%
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)), # aqui solo lineas y contronos simples
    MaxPooling2D(2, 2),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Conv2D(128, (3, 3), activation='relu'), # aqui formas 
    MaxPooling2D(2, 2),

    Flatten(),
    Dropout(0.3),                # aqui ya ves como los tumores 
    Dense(128, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)


history = model.fit(
    train_generator,
    epochs=30,                     
    validation_data=test_generator,
    
)

loss, accuracy = model.evaluate(test_generator)
print(f"Precisión en test: {accuracy:.2%}")

plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Accuracy')
plt.legend()
plt.title("Accuracy del modelo")
plt.show()
# Out:
# Epoch 1/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 126s 1s/step - accuracy: 0.7482 - loss: 0.5254 - val_accuracy: 0.8353 - val_loss: 0.3647
# Epoch 2/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 133s 1s/step - accuracy: 0.8529 - loss: 0.3431 - val_accuracy: 0.8858 - val_loss: 0.2982
# Epoch 3/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 126s 1s/step - accuracy: 0.8846 - loss: 0.2671 - val_accuracy: 0.8884 - val_loss: 0.2757
# Epoch 4/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 126s 1s/step - accuracy: 0.9172 - loss: 0.1972 - val_accuracy: 0.9004 - val_loss: 0.2262
# Epoch 5/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 182s 2s/step - accuracy: 0.9373 - loss: 0.1719 - val_accuracy: 0.9124 - val_loss: 0.2478
# Epoch 6/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 124s 1s/step - accuracy: 0.9538 - loss: 0.1257 - val_accuracy: 0.9177 - val_loss: 0.2242
# Epoch 7/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 123s 1s/step - accuracy: 0.9561 - loss: 0.1143 - val_accuracy: 0.9124 - val_loss: 0.2999
# Epoch 8/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 188s 2s/step - accuracy: 0.9639 - loss: 0.0866 - val_accuracy: 0.9363 - val_loss: 0.2146
# Epoch 9/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.9819 - loss: 0.0527 - val_accuracy: 0.9216 - val_loss: 0.2367
# Epoch 10/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9718 - loss: 0.0734 - val_accuracy: 0.9349 - val_loss: 0.2052
# Epoch 11/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - accuracy: 0.9898 - loss: 0.0311 - val_accuracy: 0.9323 - val_loss: 0.2050
# Epoch 12/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 576s 6s/step - accuracy: 0.9885 - loss: 0.0316 - val_accuracy: 0.9150 - val_loss: 0.2609
# Epoch 13/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 146s 2s/step - accuracy: 0.9737 - loss: 0.0732 - val_accuracy: 0.9349 - val_loss: 0.2478
# Epoch 14/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 308s 3s/step - accuracy: 0.9970 - loss: 0.0115 - val_accuracy: 0.9363 - val_loss: 0.2324
# Epoch 15/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 312s 3s/step - accuracy: 0.9990 - loss: 0.0082 - val_accuracy: 0.9163 - val_loss: 0.3131
# Epoch 16/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - accuracy: 0.9927 - loss: 0.0267 - val_accuracy: 0.9456 - val_loss: 0.2173
# Epoch 17/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - accuracy: 0.9902 - loss: 0.0289 - val_accuracy: 0.9309 - val_loss: 0.3175
# Epoch 18/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 125s 1s/step - accuracy: 0.9955 - loss: 0.0167 - val_accuracy: 0.9469 - val_loss: 0.2669
# Epoch 19/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9939 - loss: 0.0204 - val_accuracy: 0.9456 - val_loss: 0.2784
# Epoch 20/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.9992 - loss: 0.0055 - val_accuracy: 0.9402 - val_loss: 0.2248
# Epoch 21/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.9952 - loss: 0.0159 - val_accuracy: 0.9535 - val_loss: 0.1826
# Epoch 22/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.9938 - loss: 0.0182 - val_accuracy: 0.9363 - val_loss: 0.2183
# Epoch 23/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - accuracy: 0.9993 - loss: 0.0052 - val_accuracy: 0.9469 - val_loss: 0.2092
# Epoch 24/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 102s 1s/step - accuracy: 0.9984 - loss: 0.0041 - val_accuracy: 0.9495 - val_loss: 0.2248
# Epoch 25/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 168s 2s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9469 - val_loss: 0.2243
# Epoch 26/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 1.0000 - loss: 3.6100e-04 - val_accuracy: 0.9495 - val_loss: 0.2380
# Epoch 27/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 125s 1s/step - accuracy: 1.0000 - loss: 2.7438e-04 - val_accuracy: 0.9522 - val_loss: 0.2270
# Epoch 28/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9999 - loss: 3.2312e-04 - val_accuracy: 0.9416 - val_loss: 0.2443
# Epoch 29/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 182s 2s/step - accuracy: 0.9827 - loss: 0.0514 - val_accuracy: 0.9057 - val_loss: 0.4891
# Epoch 30/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9791 - loss: 0.0542 - val_accuracy: 0.9456 - val_loss: 0.2113
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 318ms/step - accuracy: 0.9407 - loss: 0.2367
# Precisión en test: 94.56%

# %% [markdown]
# - Ahora agregaré una capa extra que podría ayudar a detectar formas extrañas del tumor (con esto tmb el número de filtros)
# - Una capa adicional de dense --> para que junte todas las características de las capas anteriores y aprenda relaciones de las características
# - Reducir a 0.2 el dropout parece no haber overfitting, solo apaga el 20% de las neuronas
# - ### Salió peor

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Conv2D(256, (3, 3), activation='relu'),   # nueva capa
    MaxPooling2D(2, 2),

    Flatten(),
    Dropout(0.2),                              # menor dropout para conservar más señal
    Dense(256, activation='relu'),             # nueva capa densa más grande
    Dense(128, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)


history = model.fit(
    train_generator,
    epochs=30,
    validation_data=test_generator,
)

loss, accuracy = model.evaluate(test_generator)
print(f"Precisión en test: {accuracy:.2%}")

plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Accuracy')
plt.legend()
plt.title("Accuracy del modelo mejorado parte dos")
plt.show()
# Out:
# Epoch 1/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - accuracy: 0.7175 - loss: 0.5868 - val_accuracy: 0.7450 - val_loss: 0.5273
# Epoch 2/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 146s 2s/step - accuracy: 0.8116 - loss: 0.4152 - val_accuracy: 0.7769 - val_loss: 0.4290
# Epoch 3/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 122s 1s/step - accuracy: 0.8543 - loss: 0.3225 - val_accuracy: 0.8831 - val_loss: 0.2774
# Epoch 4/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.8940 - loss: 0.2621 - val_accuracy: 0.9031 - val_loss: 0.2526
# Epoch 5/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9118 - loss: 0.2281 - val_accuracy: 0.9163 - val_loss: 0.2337
# Epoch 6/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 124s 1s/step - accuracy: 0.9370 - loss: 0.1657 - val_accuracy: 0.9004 - val_loss: 0.2313
# Epoch 7/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 176s 2s/step - accuracy: 0.9475 - loss: 0.1373 - val_accuracy: 0.9084 - val_loss: 0.3127
# Epoch 8/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9515 - loss: 0.1325 - val_accuracy: 0.9376 - val_loss: 0.1543
# Epoch 9/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9659 - loss: 0.0923 - val_accuracy: 0.9416 - val_loss: 0.1806
# Epoch 10/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.9710 - loss: 0.0795 - val_accuracy: 0.9283 - val_loss: 0.1900
# Epoch 11/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.9629 - loss: 0.0971 - val_accuracy: 0.9309 - val_loss: 0.2271
# Epoch 12/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9893 - loss: 0.0336 - val_accuracy: 0.9562 - val_loss: 0.1469
# Epoch 13/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.9758 - loss: 0.0636 - val_accuracy: 0.9509 - val_loss: 0.1609
# Epoch 14/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 135s 1s/step - accuracy: 0.9905 - loss: 0.0258 - val_accuracy: 0.9349 - val_loss: 0.2111
# Epoch 15/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.9880 - loss: 0.0387 - val_accuracy: 0.9456 - val_loss: 0.2415
# Epoch 16/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - accuracy: 0.9871 - loss: 0.0421 - val_accuracy: 0.9522 - val_loss: 0.1573
# Epoch 17/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.9960 - loss: 0.0136 - val_accuracy: 0.9548 - val_loss: 0.2170
# Epoch 18/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 134s 1s/step - accuracy: 0.9961 - loss: 0.0120 - val_accuracy: 0.9495 - val_loss: 0.1755
# Epoch 19/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.9949 - loss: 0.0153 - val_accuracy: 0.9602 - val_loss: 0.1852
# Epoch 20/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.9955 - loss: 0.0138 - val_accuracy: 0.9575 - val_loss: 0.1767
# Epoch 21/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.9933 - loss: 0.0204 - val_accuracy: 0.9615 - val_loss: 0.1780
# Epoch 22/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9904 - loss: 0.0332 - val_accuracy: 0.9389 - val_loss: 0.1944
# Epoch 23/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9880 - loss: 0.0338 - val_accuracy: 0.9602 - val_loss: 0.1516
# Epoch 24/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9983 - loss: 0.0078 - val_accuracy: 0.9695 - val_loss: 0.1343
# Epoch 25/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9655 - val_loss: 0.2061
# Epoch 26/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 1.0000 - loss: 3.5004e-04 - val_accuracy: 0.9721 - val_loss: 0.1994
# Epoch 27/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 1.0000 - loss: 1.2971e-04 - val_accuracy: 0.9668 - val_loss: 0.2209
# Epoch 28/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 153s 2s/step - accuracy: 0.9999 - loss: 2.6747e-04 - val_accuracy: 0.9628 - val_loss: 0.1906
# Epoch 29/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9575 - val_loss: 0.2479
# Epoch 30/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 145s 2s/step - accuracy: 0.9965 - loss: 0.0118 - val_accuracy: 0.9363 - val_loss: 0.2137
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 355ms/step - accuracy: 0.9352 - loss: 0.2123
# Precisión en test: 93.63%

# %% [markdown]
# - Subí el dropout de nuevo para que apagara la mitad de las neuronas
# - Mantuve la cuarta capa con más filtros
# - ### Tampoco funcionó

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Conv2D(256, (3, 3), activation='relu'),   # nueva capa
    MaxPooling2D(2, 2),

    Flatten(),
    Dropout(0.5),                              # menor dropout para conservar más señal
    Dense(256, activation='relu'),             # nueva capa densa más grande
    Dense(128, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)


history = model.fit(
    train_generator,
    epochs=30,
    validation_data=test_generator,
)

loss, accuracy = model.evaluate(test_generator)
print(f"Precisión en test: {accuracy:.2%}")

plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Accuracy')
plt.legend()
plt.title("Accuracy del modelo mejorado parte dos")
plt.show()
# Out:
# Epoch 1/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.7335 - loss: 0.5441 - val_accuracy: 0.8154 - val_loss: 0.4859
# Epoch 2/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.8417 - loss: 0.3706 - val_accuracy: 0.8645 - val_loss: 0.3015
# Epoch 3/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.8803 - loss: 0.2744 - val_accuracy: 0.8818 - val_loss: 0.2825
# Epoch 4/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 145s 2s/step - accuracy: 0.8932 - loss: 0.2643 - val_accuracy: 0.8871 - val_loss: 0.2965
# Epoch 5/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.9004 - loss: 0.2512 - val_accuracy: 0.9057 - val_loss: 0.2462
# Epoch 6/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 184s 2s/step - accuracy: 0.9326 - loss: 0.1817 - val_accuracy: 0.9031 - val_loss: 0.2195
# Epoch 7/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9017 - loss: 0.2230 - val_accuracy: 0.9190 - val_loss: 0.2092
# Epoch 8/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.9481 - loss: 0.1300 - val_accuracy: 0.9110 - val_loss: 0.2268
# Epoch 9/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.9660 - loss: 0.0952 - val_accuracy: 0.9296 - val_loss: 0.1927
# Epoch 10/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.9684 - loss: 0.0838 - val_accuracy: 0.9097 - val_loss: 0.2327
# Epoch 11/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 134s 1s/step - accuracy: 0.9695 - loss: 0.0883 - val_accuracy: 0.9402 - val_loss: 0.1737
# Epoch 12/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - accuracy: 0.9806 - loss: 0.0575 - val_accuracy: 0.8539 - val_loss: 0.3515
# Epoch 13/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.9226 - loss: 0.1954 - val_accuracy: 0.9376 - val_loss: 0.1483
# Epoch 14/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.9696 - loss: 0.0786 - val_accuracy: 0.9602 - val_loss: 0.1450
# Epoch 15/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.9815 - loss: 0.0522 - val_accuracy: 0.9548 - val_loss: 0.1635
# Epoch 16/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 146s 2s/step - accuracy: 0.9918 - loss: 0.0297 - val_accuracy: 0.9522 - val_loss: 0.1921
# Epoch 17/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 199s 2s/step - accuracy: 0.9781 - loss: 0.0621 - val_accuracy: 0.9602 - val_loss: 0.1367
# Epoch 18/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9848 - loss: 0.0412 - val_accuracy: 0.9309 - val_loss: 0.2472
# Epoch 19/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - accuracy: 0.9912 - loss: 0.0259 - val_accuracy: 0.9442 - val_loss: 0.2024
# Epoch 20/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 133s 1s/step - accuracy: 0.9940 - loss: 0.0202 - val_accuracy: 0.9602 - val_loss: 0.1637
# Epoch 21/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 157s 2s/step - accuracy: 0.9881 - loss: 0.0323 - val_accuracy: 0.9734 - val_loss: 0.1509
# Epoch 22/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.9931 - loss: 0.0187 - val_accuracy: 0.9641 - val_loss: 0.1374
# Epoch 23/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.9938 - loss: 0.0148 - val_accuracy: 0.9641 - val_loss: 0.1726
# Epoch 24/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9941 - loss: 0.0165 - val_accuracy: 0.9655 - val_loss: 0.1618
# Epoch 25/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9848 - loss: 0.0378 - val_accuracy: 0.9456 - val_loss: 0.2134
# Epoch 26/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 187s 2s/step - accuracy: 0.9958 - loss: 0.0140 - val_accuracy: 0.9721 - val_loss: 0.1214
# Epoch 27/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.9983 - loss: 0.0061 - val_accuracy: 0.9615 - val_loss: 0.1816
# Epoch 28/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9947 - loss: 0.0173 - val_accuracy: 0.9641 - val_loss: 0.1709
# Epoch 29/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - accuracy: 0.9980 - loss: 0.0097 - val_accuracy: 0.9761 - val_loss: 0.1565
# Epoch 30/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.9876 - loss: 0.0329 - val_accuracy: 0.8818 - val_loss: 0.3330
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 671ms/step - accuracy: 0.9052 - loss: 0.2697
# Precisión en test: 88.18%

# %% [markdown]
# - Finalmente decidí quitar una capa, mantener el número de neuronas apagadas y funcionó mejor
# - También un aspecto importante a considerar es que mi número de epochs lo subí a 50, como lo habíamos estado haciendo en clase y tardó cerca de hora y media en correr
# - ### Esta sería la CNN con mejor accuracy pero tarda bastante

# %%
train_dir = "/Users/sabrina/Documents/UNI/A-NEUROCIENCIAS/SEXTO/MODELOS2/Neurociencias-2025-2/S03_datasets/Brain_tumor/Brain Tumor/data/train"
test_dir = "/Users/sabrina/Documents/UNI/A-NEUROCIENCIAS/SEXTO/MODELOS2/Neurociencias-2025-2/S03_datasets/Brain_tumor/Brain Tumor/data/test"

# se reescalan píxeles de 0–255 a 0–1
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# cargar img desde carpetas
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),   # Redimensionar todas las imágenes a 150x150
    batch_size=32,
    class_mode='binary'       # Clasificación binaria: tumor vs no_tumor
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)


model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Flatten(),
    Dropout(0.5),                 
    Dense(128, activation='relu'),
    Dense(1, activation='sigmoid')  # 1 salida con activación sigmoide (probabilidad)
])

model.compile(
    optimizer='adam',              # Optimizador eficiente
    loss='binary_crossentropy',    # Pérdida para clasificación binaria
    metrics=['accuracy']           # Métrica de desempeño
)

history = model.fit(
    train_generator,
    epochs=50,                     
    validation_data=test_generator
)

# evaluar modelo 
loss, accuracy = model.evaluate(test_generator)
print(f"Precisión en test: {accuracy:.2%}")



# ver entrenamiento 
plt.plot(history.history['accuracy'], label='Precisión Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Precisión Validación')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.title("Evolución de la precisión durante el entrenamiento")
plt.show()
# Out:
# Found 3009 images belonging to 2 classes.
# Found 753 images belonging to 2 classes.
# /Users/sabrina/anaconda3/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /Users/sabrina/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 127s 1s/step - accuracy: 0.7310 - loss: 0.5597 - val_accuracy: 0.8313 - val_loss: 0.3940
# Epoch 2/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 126s 1s/step - accuracy: 0.8343 - loss: 0.3775 - val_accuracy: 0.8327 - val_loss: 0.3687
# Epoch 3/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 127s 1s/step - accuracy: 0.8730 - loss: 0.3263 - val_accuracy: 0.8738 - val_loss: 0.3242
# Epoch 4/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 124s 1s/step - accuracy: 0.8719 - loss: 0.2952 - val_accuracy: 0.8752 - val_loss: 0.2775
# Epoch 5/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - accuracy: 0.8870 - loss: 0.2716 - val_accuracy: 0.8592 - val_loss: 0.3898
# Epoch 6/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 126s 1s/step - accuracy: 0.8961 - loss: 0.2796 - val_accuracy: 0.8884 - val_loss: 0.2546
# Epoch 7/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 124s 1s/step - accuracy: 0.9039 - loss: 0.2552 - val_accuracy: 0.8991 - val_loss: 0.2534
# Epoch 8/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 127s 1s/step - accuracy: 0.9132 - loss: 0.1967 - val_accuracy: 0.9044 - val_loss: 0.2433
# Epoch 9/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.9352 - loss: 0.1668 - val_accuracy: 0.9163 - val_loss: 0.1951
# Epoch 10/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 121s 1s/step - accuracy: 0.9437 - loss: 0.1471 - val_accuracy: 0.9150 - val_loss: 0.1876
# Epoch 11/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - accuracy: 0.9452 - loss: 0.1437 - val_accuracy: 0.9203 - val_loss: 0.1775
# Epoch 12/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 128s 1s/step - accuracy: 0.9545 - loss: 0.1186 - val_accuracy: 0.9376 - val_loss: 0.1760
# Epoch 13/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 128s 1s/step - accuracy: 0.9656 - loss: 0.0934 - val_accuracy: 0.9416 - val_loss: 0.1688
# Epoch 14/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.9670 - loss: 0.0847 - val_accuracy: 0.9363 - val_loss: 0.1885
# Epoch 15/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.9680 - loss: 0.0785 - val_accuracy: 0.9402 - val_loss: 0.1677
# Epoch 16/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - accuracy: 0.9778 - loss: 0.0591 - val_accuracy: 0.9495 - val_loss: 0.1564
# Epoch 17/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - accuracy: 0.9872 - loss: 0.0450 - val_accuracy: 0.9575 - val_loss: 0.1530
# Epoch 18/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 121s 1s/step - accuracy: 0.9879 - loss: 0.0353 - val_accuracy: 0.9535 - val_loss: 0.1391
# Epoch 19/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 121s 1s/step - accuracy: 0.9839 - loss: 0.0368 - val_accuracy: 0.9535 - val_loss: 0.1617
# Epoch 20/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 121s 1s/step - accuracy: 0.9872 - loss: 0.0429 - val_accuracy: 0.9562 - val_loss: 0.1402
# Epoch 21/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 124s 1s/step - accuracy: 0.9942 - loss: 0.0195 - val_accuracy: 0.9456 - val_loss: 0.1619
# Epoch 22/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9885 - loss: 0.0369 - val_accuracy: 0.9562 - val_loss: 0.1778
# Epoch 23/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 118s 1s/step - accuracy: 0.9915 - loss: 0.0227 - val_accuracy: 0.9562 - val_loss: 0.1732
# Epoch 24/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 118s 1s/step - accuracy: 0.9957 - loss: 0.0211 - val_accuracy: 0.9548 - val_loss: 0.2312
# Epoch 25/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.9886 - loss: 0.0456 - val_accuracy: 0.9641 - val_loss: 0.1648
# Epoch 26/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 133s 1s/step - accuracy: 0.9869 - loss: 0.0327 - val_accuracy: 0.9602 - val_loss: 0.1658
# Epoch 27/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - accuracy: 0.9892 - loss: 0.0357 - val_accuracy: 0.9615 - val_loss: 0.1338
# Epoch 28/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - accuracy: 0.9945 - loss: 0.0156 - val_accuracy: 0.9615 - val_loss: 0.1489
# Epoch 29/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - accuracy: 0.9977 - loss: 0.0073 - val_accuracy: 0.9681 - val_loss: 0.1666
# Epoch 30/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - accuracy: 0.9999 - loss: 0.0062 - val_accuracy: 0.9655 - val_loss: 0.1906
# Epoch 31/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.9974 - loss: 0.0087 - val_accuracy: 0.9389 - val_loss: 0.1920
# Epoch 32/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - accuracy: 0.9888 - loss: 0.0334 - val_accuracy: 0.9562 - val_loss: 0.1931
# Epoch 33/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 125s 1s/step - accuracy: 0.9909 - loss: 0.0228 - val_accuracy: 0.9416 - val_loss: 0.2592
# Epoch 34/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 124s 1s/step - accuracy: 0.9906 - loss: 0.0241 - val_accuracy: 0.9655 - val_loss: 0.2410
# Epoch 35/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 122s 1s/step - accuracy: 0.9938 - loss: 0.0200 - val_accuracy: 0.9548 - val_loss: 0.1956
# Epoch 36/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 125s 1s/step - accuracy: 0.9968 - loss: 0.0176 - val_accuracy: 0.9495 - val_loss: 0.2876
# Epoch 37/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.9921 - loss: 0.0181 - val_accuracy: 0.9681 - val_loss: 0.1398
# Epoch 38/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9982 - loss: 0.0051 - val_accuracy: 0.9602 - val_loss: 0.1839
# Epoch 39/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.9973 - loss: 0.0074 - val_accuracy: 0.9681 - val_loss: 0.1920
# Epoch 40/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.9968 - loss: 0.0097 - val_accuracy: 0.9588 - val_loss: 0.1799
# Epoch 41/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 119s 1s/step - accuracy: 0.9959 - loss: 0.0148 - val_accuracy: 0.9641 - val_loss: 0.1743
# Epoch 42/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9988 - loss: 0.0028 - val_accuracy: 0.9641 - val_loss: 0.1907
# Epoch 43/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 132s 1s/step - accuracy: 0.9967 - loss: 0.0056 - val_accuracy: 0.9641 - val_loss: 0.2174
# Epoch 44/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 132s 1s/step - accuracy: 0.9946 - loss: 0.0134 - val_accuracy: 0.9562 - val_loss: 0.1833
# Epoch 45/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 134s 1s/step - accuracy: 0.9965 - loss: 0.0084 - val_accuracy: 0.9668 - val_loss: 0.1362
# Epoch 46/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 133s 1s/step - accuracy: 0.9990 - loss: 0.0033 - val_accuracy: 0.9655 - val_loss: 0.2143
# Epoch 47/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9695 - val_loss: 0.1781
# Epoch 48/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 133s 1s/step - accuracy: 0.9996 - loss: 0.0016 - val_accuracy: 0.9681 - val_loss: 0.2428
# Epoch 49/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 132s 1s/step - accuracy: 0.9971 - loss: 0.0068 - val_accuracy: 0.9548 - val_loss: 0.1737
# Epoch 50/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 128s 1s/step - accuracy: 0.9933 - loss: 0.0258 - val_accuracy: 0.9668 - val_loss: 0.2170
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 356ms/step - accuracy: 0.9789 - loss: 0.1882
# Precisión en test: 96.68%

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier

# no usamos imagen porque no sirve de nada y class en realidad es el valor que queremos que nos devuelva 
X = df.drop(columns=['Image', 'Class'])
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

modelos = {
    'KNN (k=5)': KNeighborsClassifier(n_neighbors=5),
    'SVM (RBF)': SVC(kernel='rbf'),
    'LDA': LinearDiscriminantAnalysis(),
    'Random Forest': RandomForestClassifier(n_estimators=100, random_state=42)
}

# entrenar y evaluar cada modelo
resultados = {}
for nombre, modelo in modelos.items():
    modelo.fit(X_train, y_train)
    y_pred = modelo.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    resultados[nombre] = acc

resultados
# Out:
# {'KNN (k=5)': 0.7861885790172642,
#  'SVM (RBF)': 0.796812749003984,
#  'LDA': 0.9760956175298805,
#  'Random Forest': 0.9933598937583001}

# %% [markdown]
# ### Después comparé las características que obtuvimos de las imágenes (kurtosis, entropía, etc) con otros modelos supervisados que no son para imágenes y tuvieron un accuracy aún más alto (LDA y Random Forest)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# matrices de confusión
for nombre, modelo in modelos.items():
    y_pred = modelo.predict(X_test)
    cm = confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(4, 3))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['No Tumor', 'Tumor'],
                yticklabels=['No Tumor', 'Tumor'])
    plt.title(f'Matriz de Confusión - {nombre}')
    plt.xlabel('Predicción')
    plt.ylabel('Real')
    plt.tight_layout()
    plt.show()
